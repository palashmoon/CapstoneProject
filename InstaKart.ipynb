# %%
# import all modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Market_Basket_Optimisation.csv' , header =None)

# %%
data.shape
# Out:
# (7501, 20)

# %%
data.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
plt.figure(figsize=(28,10))
data[0].value_counts().plot.bar(color = 'blue')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
#  We can consider each observation or each row as a product which is buyed by a coustomer. And all the NaN value which are that mean those these are the missing value and we need to remove it.

# %%
data = data.replace(np.nan , '')
data
# Out:
#                      0                  1                  2   \
# 0                shrimp            almonds            avocado
# 1               burgers          meatballs               eggs
# 2               chutney
# 3                turkey            avocado
# 4         mineral water               milk         energy bar
# 5        low fat yogurt
# 6     whole wheat pasta       french fries
# 7                  soup        light cream            shallot
# 8     frozen vegetables          spaghetti          green tea
# 9          french fries
# 10                 eggs           pet food
# 11              cookies
# 12               turkey            burgers      mineral water
# 13            spaghetti          champagne            cookies
# 14        mineral water             salmon
# 15        mineral water
# 16               shrimp          chocolate            chicken
# 17               turkey               eggs
# 18               turkey         fresh tuna           tomatoes
# ...

# %%
# we will create a list of all customer and each customer will have one list.
customer_bought_list = []
for i in range(7501):
    customer_bought_list.append([str(data.values[i,j]) for j in range(20) if str(data.values[i,j])!= ''])

# %%
customer_bought_list = np.array(customer_bought_list)
customer_bought_list
# Out:
# array([list(['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil']),
#        list(['burgers', 'meatballs', 'eggs']), list(['chutney']), ...,
#        list(['chicken']), list(['escalope', 'green tea']),
#        list(['eggs', 'frozen smoothie', 'yogurt cake', 'low fat yogurt'])],
#       dtype=object)

# %%
customer_bought_list[0]
# Out:
# ['shrimp',
#  'almonds',
#  'avocado',
#  'vegetables mix',
#  'green grapes',
#  'whole weat flour',
#  'yams',
#  'cottage cheese',
#  'energy drink',
#  'tomato juice',
#  'low fat yogurt',
#  'green tea',
#  'honey',
#  'salad',
#  'mineral water',
#  'salmon',
#  'antioxydant juice',
#  'frozen smoothie',
#  'spinach',
#  'olive oil']
